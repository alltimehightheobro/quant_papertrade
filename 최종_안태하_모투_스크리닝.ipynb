# %% [markdown]
# <a href="https://colab.research.google.com/github/alltimehightheobro/quant_papertrade/blob/main/%EC%B5%9C%EC%A2%85_%EC%95%88%ED%83%9C%ED%95%98_%EB%AA%A8%ED%88%AC_%EC%8A%A4%ED%81%AC%EB%A6%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
mpl.rc('font', family = 'Malgun Gothic')
import matplotlib.pyplot as plt
import datetime
import math
import openpyxl
import plotly.graph_objects as go # 그래프 그릴 때 사용할 라이브러리입니다.
from plotly.subplots import make_subplots

# %%
# 경로 복사 -> 주소에 붙여넣기
# KOSDAQ.xlxs
opercf=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DART/안태하_스크리닝.xlsx', sheet_name="영업활동현금흐름",index_col=0)
netincome=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DART/안태하_스크리닝.xlsx', sheet_name="당기순이익",index_col=0)
quickratio=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DART/안태하_스크리닝.xlsx',sheet_name="당좌비율", index_col=0)
pbr=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DART/안태하_스크리닝.xlsx', sheet_name="PBR", index_col=0)
revenuey=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DART/안태하_스크리닝.xlsx', sheet_name="3년평균_매출액증가율",index_col=0)
# 주가.xlsx
price_data=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/DART/dartworkspace/주가.xlsx', index_col=0)

# %% [markdown]
# ## 1. 최근 3년간 영업활동현금흐름 0 이상

# %%
opercf = opercf.T
new_opercf=opercf.iloc[:, -3:]
new_opercf
# Out:
# Symbol     2020-12-31    2021-12-31    2022-12-31
# A010120  2.889010e+08  1.015445e+08 -1.454465e+08
# A001450  1.219233e+09  1.006023e+09  1.739003e+09
# A003410  3.858910e+08  3.811723e+08  2.281382e+08
# A004990  3.825663e+08  6.004652e+08  9.041409e+08
# A028670  4.704850e+08  7.676870e+08  1.410763e+09
# ...               ...           ...           ...
# A435870           NaN           NaN -3.570489e+04
# A418210           NaN           NaN -3.018614e+04
# A373340 -9.555000e+03 -2.629630e+04  5.740090e+03
# A438580           NaN           NaN -1.955998e+04
# A413600           NaN -3.387480e+03 -5.957395e+04
#
# [2211 rows x 3 columns]

# %%
new_opercf>=0
# Out:
# Symbol   2020-12-31  2021-12-31  2022-12-31
# A010120        True        True       False
# A001450        True        True        True
# A003410        True        True        True
# A004990        True        True        True
# A028670        True        True        True
# ...             ...         ...         ...
# A435870       False       False       False
# A418210       False       False       False
# A373340       False       False        True
# A438580       False       False       False
# A413600       False       False       False
#
# [2211 rows x 3 columns]

# %%
new_opercf=new_opercf[new_opercf>=0]
new_opercf
# Out:
# Symbol     2020-12-31    2021-12-31    2022-12-31
# A010120  2.889010e+08  1.015445e+08           NaN
# A001450  1.219233e+09  1.006023e+09  1.739003e+09
# A003410  3.858910e+08  3.811723e+08  2.281382e+08
# A004990  3.825663e+08  6.004652e+08  9.041409e+08
# A028670  4.704850e+08  7.676870e+08  1.410763e+09
# ...               ...           ...           ...
# A435870           NaN           NaN           NaN
# A418210           NaN           NaN           NaN
# A373340           NaN           NaN  5.740090e+03
# A438580           NaN           NaN           NaN
# A413600           NaN           NaN           NaN
#
# [2211 rows x 3 columns]

# %%
new_opercf.dropna(axis=0, inplace=True)
new_opercf
# Out:
# Symbol     2020-12-31    2021-12-31    2022-12-31
# A001450  1.219233e+09  1.006023e+09  1.739003e+09
# A003410  3.858910e+08  3.811723e+08  2.281382e+08
# A004990  3.825663e+08  6.004652e+08  9.041409e+08
# A028670  4.704850e+08  7.676870e+08  1.410763e+09
# A004370  2.314917e+08  1.626843e+08  1.596504e+08
# ...               ...           ...           ...
# A067770  6.298388e+06  4.220818e+06  2.274410e+06
# A070300  5.612391e+05  4.375606e+05  8.677085e+05
# A096870  1.674708e+06  3.594600e+05  3.318727e+06
# A046070  1.887118e+07  1.551065e+07  1.449817e+07
# A121890  4.828677e+06  7.331885e+05  3.574514e+05
#
# [925 rows x 3 columns]

# %% [markdown]
# ## 2. 최근 3개년도 당기순이익 0 이상

# %%
netincome = netincome.T
new_netincome=netincome.iloc[:, -3:]
new_netincome
# Out:
# Symbol     2020-12-31    2021-12-31    2022-12-31
# A010120  8.548555e+07  8.531035e+07  9.121000e+07
# A001450  3.318539e+08  4.325724e+08  5.745572e+08
# A003410  1.381814e+08  1.859572e+08  1.277801e+08
# A004990 -2.388790e+08  1.504338e+08  3.365710e+08
# A028670  9.072200e+07  5.493050e+08  6.770810e+08
# ...               ...           ...           ...
# A435870           NaN           NaN  4.137541e+04
# A418210           NaN           NaN  1.374311e+04
# A373340 -9.508000e+03 -1.815188e+04  2.579056e+04
# A438580           NaN           NaN  1.675911e+04
# A413600           NaN -7.959050e+03  8.151270e+03
#
# [2211 rows x 3 columns]

# %%
new_netincome=new_netincome[new_netincome>=0]
new_netincome
# Out:
# Symbol     2020-12-31    2021-12-31    2022-12-31
# A010120  8.548555e+07  8.531035e+07  9.121000e+07
# A001450  3.318539e+08  4.325724e+08  5.745572e+08
# A003410  1.381814e+08  1.859572e+08  1.277801e+08
# A004990           NaN  1.504338e+08  3.365710e+08
# A028670  9.072200e+07  5.493050e+08  6.770810e+08
# ...               ...           ...           ...
# A435870           NaN           NaN  4.137541e+04
# A418210           NaN           NaN  1.374311e+04
# A373340           NaN           NaN  2.579056e+04
# A438580           NaN           NaN  1.675911e+04
# A413600           NaN           NaN  8.151270e+03
#
# [2211 rows x 3 columns]

# %%
new_netincome.dropna(axis=0, inplace=True)
new_netincome
# Out:
# Symbol     2020-12-31    2021-12-31    2022-12-31
# A010120  8.548555e+07  8.531035e+07  9.121000e+07
# A001450  3.318539e+08  4.325724e+08  5.745572e+08
# A003410  1.381814e+08  1.859572e+08  1.277801e+08
# A028670  9.072200e+07  5.493050e+08  6.770810e+08
# A004370  1.490483e+08  9.963736e+07  1.160336e+08
# ...               ...           ...           ...
# A060480  9.373419e+04  8.679902e+05  1.006346e+06
# A106240  6.313680e+06  5.354727e+07  2.513987e+08
# A275630  5.630467e+04  1.649776e+06  1.897480e+06
# A134060  5.368624e+05  1.700443e+06  2.859074e+06
# A096870  1.348523e+06  2.230021e+06  1.954192e+06
#
# [992 rows x 3 columns]

# %% [markdown]
# ## 3. 당좌비율 170프로 이상

# %%
quickratio = quickratio.T
new_quickratio=quickratio.iloc[:, -1:]
new_quickratio
# Out:
# Symbol   2022-12-31
# A010120      139.09
# A001450         NaN
# A003410       35.24
# A004990       50.80
# A028670      129.05
# ...             ...
# A435870         NaN
# A418210         NaN
# A373340         NaN
# A438580         NaN
# A413600         NaN
#
# [2211 rows x 1 columns]

# %%
new_quickratio=new_quickratio[new_quickratio>=170]
new_quickratio.dropna(axis=0, inplace=True)
new_quickratio
# Out:
# Symbol   2022-12-31
# A002790     2673.85
# A000990      308.65
# A111770      281.83
# A006740      232.56
# A012750      207.16
# ...             ...
# A067770     3278.05
# A070300     1815.55
# A096870      588.66
# A174880      408.07
# A121890      186.11
#
# [783 rows x 1 columns]

# %% [markdown]
# ## 4. 3년 평균 대비 매출액 15프로 증가

# %%
revenuey = revenuey.T
new_revenuey = revenuey.iloc[:, -1:]
new_revenuey
# Out:
# Symbol   44926
# A010120  12.90
# A001450    NaN
# A003410   8.50
# A004990  16.80
# A028670  37.53
# ...        ...
# A435870    NaN
# A418210    NaN
# A373340    NaN
# A438580    NaN
# A413600    NaN
#
# [2211 rows x 1 columns]

# %%
new_revenuey=new_revenuey[new_revenuey>15]
new_revenuey.dropna(axis=0, inplace=True)
new_revenuey
# Out:
# Symbol   44926
# A004990  16.80
# A028670  37.53
# A002380  35.56
# A036460  27.45
# A000990  27.55
# ...        ...
# A069330  34.32
# A223310  31.81
# A033790  25.77
# A050090  22.65
# A096870  19.03
#
# [606 rows x 1 columns]

# %% [markdown]
# ## 5. PBR 1 이하인 주식

# %%
pbr = pbr.T
new_pbr = pbr
new_pbr = new_pbr[new_pbr<=1]
new_pbr.dropna(axis=0, inplace=True)
new_pbr
# Out:
# Symbol   2022-12-31
# A001450     0.61316
# A004990     0.35986
# A028670     0.68181
# A004370     0.91051
# A088350     0.31238
# ...             ...
# A044180     0.50401
# A424140     0.98871
# A440200     0.98173
# A174880     0.27084
# A121890     0.99984
#
# [1018 rows x 1 columns]

# %%
list1 = new_netincome.index.values.tolist()
list2 = new_opercf.index.values.tolist()
list3 = new_quickratio.index.values.tolist()
list4 = new_revenuey.index.values.tolist()
list5 = new_pbr.index.values.tolist()

# %%
list1

# %%
common_values = list(set(list1) & set(list2) & set(list3) & set(list4) & set(list5))
len(common_values)
# Out:
# 36

# %%
common_values
# Out:
# ['A111770',
#  'A036800',
#  'A017890',
#  'A147830',
#  'A098120',
#  'A031980',
#  'A001880',
#  'A095610',
#  'A083450',
#  'A072950',
#  'A114630',
#  'A000990',
#  'A001940',
#  'A170030',
#  'A260970',
#  'A029460',
#  'A027410',
#  'A054040',
#  'A352700',
#  'A004830',
#  'A009970',
#  'A225220',
#  'A004000',
#  'A093190',
#  'A005850',
#  'A064480',
#  'A068790',
#  'A080000',
#  'A007700',
#  'A024090',
#  'A189690',
#  'A017650',
#  'A005010',
#  'A050960',
#  'A377740',
#  'A002810']
